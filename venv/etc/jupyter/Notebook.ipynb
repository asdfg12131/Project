# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_json("/Users/antonovegor/Downloads/Project/venv/deviation.json")
print(df.columns)
# Out:
# Index(['name', 'gt_corners', 'rb_corners', 'mean', 'max', 'min', 'floor_mean',
#        'floor_max', 'floor_min', 'ceiling_mean', 'ceiling_max', 'ceiling_min'],
#       dtype='object')

# %%
x = df.ceiling_mean
y = df.floor_mean
plt.scatter(x, y)
plt.show()

# %%
s = np.polyfit(x,y,1)
y_1 = s[0] * x + s[1] 
plt.scatter(x, y)
plt.plot(x, y_1, color="red")

# %%
plt.plot([4, 6, 8], [9.856579158486156, 17.74685519936543, 23.588692605399995])

plt.show()

# %%
x_2 = df[df.gt_corners == 4]["mean"]
x_2 = list(x_2)
x_3= df[df.gt_corners == 6]["mean"]
x_3 = list(x_3)
x_4= df[df.gt_corners == 8]["mean"]
x_4 = list(x_4)
plt.hist(x_2)
plt.hist(x_3, color = "red")
plt.hist(x_4, color = "yellow")

plt.show()

# %%
plt.scatter(df.ceiling_min, df.ceiling_max)

# %%
plt.scatter(df.floor_min, df.floor_max, color = "red")
